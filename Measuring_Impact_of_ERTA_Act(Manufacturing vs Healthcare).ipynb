# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import re

# %%
#  Re-read your dataset without using the first row as header
current_cost_net_stock_private_fixed_assets_industry_manufacturing = pd.read_csv(
    '/Users/tanishagauns/Desktop/Project paper/New Data/current_cost_net_stock_private_fixed_assets_industry_manufacturing_1990 - Sheet1.csv',
    header=None
)

# Dynamically assign column names: Industry + 1975–1989
current_cost_net_stock_private_fixed_assets_industry_manufacturing.columns = ['Industry'] + list(range(1975, 1991))

# Display the clean dataset
current_cost_net_stock_private_fixed_assets_industry_manufacturing.head(14)
# Out:
#                                             Industry   1975   1976   1977  \
# 0                                      Durable goods  247.7  269.4  299.6
# 1                                      Wood products    9.5   10.4   11.7
# 2                       Nonmetallic mineral products   19.2   20.7   22.8
# 3                                     Primary metals   55.5   60.0   66.1
# 4                          Fabricated metal products   27.0   29.7   33.6
# 5                                          Machinery   26.5   29.2   32.9
# 6                   Computer and electronic products   36.7   40.0   44.5
# 7   Electrical equipment, appliances, and components   14.6   15.8   17.1
# 8     Motor vehicles, bodies and trailers, and parts   25.6   27.4   31.0
# 9                     Other transportation equipment   18.6   20.1   21.9
# 10                    Furniture and related products    2.7    2.9    3.3
# 11                       Miscellaneous manufacturing   11.8   13.2   14.8
# 12                                  Nondurable goods  200.5  221.5  247.6
#
#      1978   1979   1980   1981   1982   1983   1984   1985   1986   1987  \
# 0   338.7  392.3  453.7  506.7  538.9  554.2  583.8  621.7  656.4  688.8
# 1    13.4   15.6   17.8   19.0   19.4   19.3   19.7   20.3   21.0   21.6
# 2    25.7   29.3   33.5   36.2   37.3   37.4   38.6   40.8   42.8   44.7
# 3    72.5   81.4   91.4   98.6  101.7  102.1  103.2  105.5  106.7  108.5
# 4    38.5   44.9   52.1   58.1   61.5   62.4   65.0   68.8   72.7   76.2
# 5    37.9   44.8   52.8   60.3   65.7   68.6   72.9   77.9   81.5   84.9
# 6    50.7   59.6   70.7   81.0   89.2   95.1  104.4  113.9  122.0  130.1
# 7    19.0   21.7   25.1   28.0   30.1   31.5   33.6   35.5   37.3   38.2
# 8    35.9   42.0   48.6   55.7   57.2   55.8   57.3   61.5   66.6   70.6
# 9    24.7   29.1   34.3   39.0   43.5   47.1   52.2   57.9   63.9   69.2
# 10    3.8    4.3    5.0    5.4    5.8    6.0    6.4    6.9    7.4    7.9
# 11   16.7   19.5   22.6   25.3   27.5   28.8   30.6   32.7   34.5   36.9
# 12  279.1  320.3  367.0  404.5  432.3  448.4  468.9  494.2  518.3  544.2
#
#      1988   1989   1990
# 0   717.2  749.6  784.2
# 1    22.2   22.8   23.5
# 2    46.1   47.9   49.8
# 3   111.0  114.1  117.8
# 4    79.1   82.3   86.3
# 5    88.3   92.4   97.1
# 6   138.5  147.3  156.3
# 7    39.5   41.1   42.9
# 8    71.9   75.0   78.8
# 9    73.4   76.7   79.3
# 10    8.4    9.0    9.5
# 11   38.8   41.0   43.1
# 12  575.0  611.0  652.8

# %%
current_cost_net_stock_private_fixed_assets_industry_manufacturing.columns = ['Industry',] + [str(i) + '_net_stock' for i in range(1975, 1991)]
current_cost_net_stock_private_fixed_assets_industry_manufacturing.columns
# Out:
# Index(['Industry', '1975_net_stock', '1976_net_stock', '1977_net_stock',
#        '1978_net_stock', '1979_net_stock', '1980_net_stock', '1981_net_stock',
#        '1982_net_stock', '1983_net_stock', '1984_net_stock', '1985_net_stock',
#        '1986_net_stock', '1987_net_stock', '1988_net_stock', '1989_net_stock',
#        '1990_net_stock'],
#       dtype='object')

# %%
# Re-read your dataset without using the first row as header
current_cost_net_stock_private_fixed_assets_industry_healthcare = pd.read_csv(
     '/Users/tanishagauns/Desktop/Project paper/New Data/current_cost_net_stock_private_fixed_assets_industry_healthcareet_1990 - Sheet1.csv',
    header=None
)

# Dynamically assign column names: Industry + 1975–1990
current_cost_net_stock_private_fixed_assets_industry_healthcare.columns = ['Industry'] + list(range(1975, 1991))

# Display the clean dataset
current_cost_net_stock_private_fixed_assets_industry_healthcare.head(14)
# Out:
#                                   Industry  1975  1976  1977  1978   1979  \
# 0          Ambulatory health care services  26.3  28.5  31.8  35.8   41.1
# 1                                Hospitals  63.3  70.3  79.4  90.3  104.0
# 2  Nursing and residential care facilities   3.7   4.0   4.5   5.0    5.8
# 3                        Social assistance   3.8   4.1   4.6   5.2    5.9
#
#     1980   1981   1982   1983   1984   1985   1986   1987   1988   1989   1990
# 0   47.1   53.2   59.6   66.1   73.4   80.0   88.2   96.5  105.6  114.9  124.4
# 1  118.5  131.1  142.7  153.5  165.6  175.4  187.8  200.9  215.3  230.8  246.4
# 2    6.6    7.3    8.0    8.7    9.6   10.4   11.3   12.3   13.4   14.6   15.8
# 3    6.7    7.4    7.9    8.3    8.9    9.5   10.2   11.0   11.8   12.7   13.4

# %%
current_cost_net_stock_private_fixed_assets_industry_healthcare.columns = ['Industry',] + [str(i) + '_net_stock' for i in range(1975, 1991)]
current_cost_net_stock_private_fixed_assets_industry_healthcare.columns
# Out:
# Index(['Industry', '1975_net_stock', '1976_net_stock', '1977_net_stock',
#        '1978_net_stock', '1979_net_stock', '1980_net_stock', '1981_net_stock',
#        '1982_net_stock', '1983_net_stock', '1984_net_stock', '1985_net_stock',
#        '1986_net_stock', '1987_net_stock', '1988_net_stock', '1989_net_stock',
#        '1990_net_stock'],
#       dtype='object')

# %%
#  Re-read your dataset without using the first row as header
investment_private_equipment_industry_manufacturing = pd.read_csv(
    '/Users/tanishagauns/Desktop/Project paper/New Data/investment_private_equipment_industry_manufacturing_1990 - Sheet1.csv',
    header=None
)

# Dynamically assign column names: Industry + 1975–1991
investment_private_equipment_industry_manufacturing.columns = ['Industry'] + list(range(1975, 1991))

# Display the clean dataset
investment_private_equipment_industry_manufacturing.head(14)
# Out:
#                                             Industry  1975  1976  1977  1978  \
# 0                                      Durable goods  15.8  17.1  20.8  25.1
# 1                                      Wood products   0.9   0.9   1.2   1.4
# 2                       Nonmetallic mineral products   1.4   1.4   1.7   2.3
# 3                                     Primary metals   3.3   3.4   3.7   3.9
# 4                          Fabricated metal products   2.0   2.1   2.6   3.0
# 5                                          Machinery   1.7   1.8   2.3   3.0
# 6                   Computer and electronic products   2.3   2.6   3.1   3.8
# 7   Electrical equipment, appliances, and components   0.7   0.8   0.9   1.1
# 8     Motor vehicles, bodies and trailers, and parts   1.8   2.0   2.9   3.7
# 9                     Other transportation equipment   0.7   0.9   0.9   1.2
# 10                    Furniture and related products   0.1   0.2   0.2   0.3
# 11                       Miscellaneous manufacturing   0.9   1.2   1.3   1.4
# 12                                  Nondurable goods  14.7  16.3  18.6  20.4
#
#     1979  1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990
# 0   28.9  33.0  39.0  31.6  28.5  37.5  41.1  37.3  37.6  36.0  42.3  44.0
# 1    1.7   1.6   1.4   1.1   1.0   1.3   1.4   1.4   1.5   1.4   1.7   1.6
# 2    2.4   2.9   2.7   2.0   1.7   2.4   2.8   2.5   2.6   2.2   2.9   2.7
# 3    4.3   4.6   5.4   3.9   3.9   4.0   4.4   3.0   3.6   4.2   4.8   5.0
# 4    3.4   3.9   4.6   3.7   3.0   4.0   4.4   4.4   4.5   4.2   4.7   4.9
# 5    3.6   4.0   4.8   4.4   3.9   4.8   5.0   4.2   4.3   4.3   4.8   5.1
# 6    4.5   5.4   6.3   6.3   6.4   8.6   8.9   7.8   7.8   8.4   9.7  10.1
# 7    1.4   1.8   1.8   1.9   2.1   2.9   3.0   2.1   2.1   2.3   2.6   2.7
# 8    4.0   4.5   7.3   3.6   2.3   4.1   5.3   5.3   5.3   3.2   4.9   5.6
# 9    1.7   2.2   2.4   2.4   2.2   2.9   3.2   3.1   3.1   3.0   2.9   3.2
# 10   0.3   0.3   0.4   0.4   0.4   0.5   0.5   0.6   0.6   0.6   0.7   0.7
# 11   1.6   1.8   2.0   1.9   1.7   2.1   2.1   2.3   2.3   2.3   2.6   2.4
# 12  22.3  24.7  27.2  27.3  25.4  28.7  31.1  30.2  30.2  34.9  41.8  45.7

# %%
investment_private_equipment_industry_manufacturing.columns = ['Industry',] + [str(i) + '_equipment' for i in range(1975, 1991)]
investment_private_equipment_industry_manufacturing.columns
# Out:
# Index(['Industry', '1975_equipment', '1976_equipment', '1977_equipment',
#        '1978_equipment', '1979_equipment', '1980_equipment', '1981_equipment',
#        '1982_equipment', '1983_equipment', '1984_equipment', '1985_equipment',
#        '1986_equipment', '1987_equipment', '1988_equipment', '1989_equipment',
#        '1990_equipment'],
#       dtype='object')

# %%
# Re-read your dataset without using the first row as header
investment_private_equipment_industry_healthcare = pd.read_csv(
    '/Users/tanishagauns/Desktop/Project paper/New Data/investment_private_equipment_industry_healthcare_1990 - Sheet1.csv',
    header=None
)

# Dynamically assign column names: Industry + 1975–1990
investment_private_equipment_industry_healthcare.columns = ['Industry'] + list(range(1975, 1991))

# Display the clean dataset
investment_private_equipment_industry_healthcare.head(14)
# Out:
#                                   Industry  1975  1976  1977  1978  1979  \
# 0          Ambulatory health care services   1.8   2.1   2.5   3.0   3.2
# 1                                Hospitals   2.5   3.0   3.1   3.6   3.8
# 2  Nursing and residential care facilities   0.1   0.1   0.2   0.2   0.2
# 3                        Social assistance   0.1   0.2   0.2   0.2   0.3
#
#    1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990
# 0   3.6   4.4   5.4   6.4   7.0   6.9   7.6   8.5   9.7  10.6  11.5
# 1   4.1   4.7   5.5   6.2   6.9   7.0   7.6   8.5   9.5  10.6  11.6
# 2   0.3   0.3   0.4   0.5   0.5   0.5   0.5   0.5   0.7   0.8   0.9
# 3   0.3   0.3   0.2   0.3   0.3   0.3   0.4   0.4   0.4   0.5   0.5

# %%
investment_private_equipment_industry_healthcare.columns = ['Industry',] + [str(i) + '_equipment' for i in range(1975, 1991)]
investment_private_equipment_industry_healthcare.columns
# Out:
# Index(['Industry', '1975_equipment', '1976_equipment', '1977_equipment',
#        '1978_equipment', '1979_equipment', '1980_equipment', '1981_equipment',
#        '1982_equipment', '1983_equipment', '1984_equipment', '1985_equipment',
#        '1986_equipment', '1987_equipment', '1988_equipment', '1989_equipment',
#        '1990_equipment'],
#       dtype='object')

# %%
# Re-read your dataset without using the first row as header
investment_private_fixed_assets_industry_manufacturing = pd.read_csv(
    '/Users/tanishagauns/Desktop/Project paper/New Data/investment_private_fixed_assets_industry_manufacturing_1990 - Sheet1.csv',
    header=None
)

# Dynamically assign column names: Industry + 1975–1990 (adjust based on column count)
investment_private_fixed_assets_industry_manufacturing.columns = ['Industry'] + list(range(1975, 1991))

# Display the clean dataset
investment_private_fixed_assets_industry_manufacturing.head(14)
# Out:
#                                             Industry  1975  1976  1977  1978  \
# 0                                      Durable goods  32.9  35.3  40.9  49.3
# 1                                      Wood products   1.2   1.2   1.6   1.9
# 2                       Nonmetallic mineral products   2.1   2.1   2.5   3.3
# 3                                     Primary metals   4.9   4.8   5.1   5.4
# 4                          Fabricated metal products   3.1   3.2   3.7   4.5
# 5                                          Machinery   3.8   3.9   4.7   5.9
# 6                   Computer and electronic products   7.0   7.7   8.7  10.5
# 7   Electrical equipment, appliances, and components   2.0   2.2   2.3   2.7
# 8     Motor vehicles, bodies and trailers, and parts   4.4   5.1   6.8   8.2
# 9                     Other transportation equipment   2.5   2.9   3.1   4.0
# 10                    Furniture and related products   0.3   0.3   0.4   0.5
# 11                       Miscellaneous manufacturing   1.6   2.0   2.1   2.4
# 12                                  Nondurable goods  24.5  26.5  29.4  32.8
#
#     1979  1980  1981  1982  1983  1984  1985  1986  1987  1988  1989   1990
# 0   56.6  65.4  75.6  69.3  66.8  82.2  91.6  88.4  88.8  89.2  99.9  103.6
# 1    2.2   2.2   2.0   1.5   1.4   1.8   1.8   1.8   1.9   1.8   2.1    2.0
# 2    3.4   4.1   3.9   3.0   2.8   3.8   4.6   4.2   4.3   4.0   4.8    4.8
# 3    5.9   6.3   7.6   5.7   5.6   5.6   6.4   4.6   5.2   5.9   6.9    7.4
# 4    4.9   5.7   6.7   5.6   4.8   6.2   6.9   6.7   6.7   6.5   7.4    7.8
# 5    6.9   7.9   9.4   9.1   8.2   9.9  10.5   9.0   8.9   9.3  10.7   11.4
# 6   12.5  15.1  17.1  17.9  18.4  22.7  24.4  23.3  24.1  25.8  27.9   29.3
# 7    3.2   3.8   4.3   4.2   4.4   5.2   5.2   5.0   4.0   4.5   5.0    5.3
# 8    9.1  10.3  13.3   9.5   8.2  11.0  13.6  15.0  14.5  12.5  15.5   16.3
# 9    5.1   6.2   7.0   8.2   8.7  10.9  12.5  13.5  13.3  12.9  13.0   12.5
# 10   0.5   0.6   0.6   0.6   0.7   0.8   0.8   0.9   0.9   1.0   1.1    1.0
# 11   2.8   3.2   3.7   4.0   3.7   4.3   4.7   4.4   5.0   5.0   5.6    5.8
# 12  36.5  40.8  45.7  46.9  45.0  50.7  54.5  52.0  53.8  60.9  72.1   79.0

# %%
investment_private_fixed_assets_industry_manufacturing.columns = ['Industry',] + [str(i) + '_fixed_assets' for i in range(1975, 1991)]
investment_private_fixed_assets_industry_manufacturing.columns
# Out:
# Index(['Industry', '1975_fixed_assets', '1976_fixed_assets',
#        '1977_fixed_assets', '1978_fixed_assets', '1979_fixed_assets',
#        '1980_fixed_assets', '1981_fixed_assets', '1982_fixed_assets',
#        '1983_fixed_assets', '1984_fixed_assets', '1985_fixed_assets',
#        '1986_fixed_assets', '1987_fixed_assets', '1988_fixed_assets',
#        '1989_fixed_assets', '1990_fixed_assets'],
#       dtype='object')

# %%
# Re-read your dataset without using the first row as header
investment_private_fixed_assets_industry_healthcare = pd.read_csv(
    '/Users/tanishagauns/Desktop/Project paper/New Data/investment_private_fixed_assets_industry_healthcare _1990 - Sheet1.csv',
    header=None
)

# Dynamically assign column names: Industry + 1975–1990 (adjust based on column count)
investment_private_fixed_assets_industry_healthcare.columns = ['Industry'] + list(range(1975, 1991))

# Display the clean dataset
investment_private_fixed_assets_industry_healthcare.head(14)
# Out:
#                                   Industry  1975  1976  1977  1978  1979  \
# 0          Ambulatory health care services   2.4   2.7   3.1   3.8   4.3
# 1                                Hospitals   5.9   6.6   6.9   7.3   7.8
# 2  Nursing and residential care facilities   0.2   0.3   0.3   0.4   0.4
# 3                        Social assistance   0.3   0.3   0.4   0.4   0.5
#
#    1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990
# 0   5.1   6.6   8.6   9.9  11.3  12.1  13.2  14.8  15.9  16.9  11.5
# 1   8.5   9.7  12.3  13.6  13.9  14.5  16.2  18.4  20.3  22.4  11.6
# 2   0.5   0.6   0.8   0.9   1.1   1.2   1.3   1.5   1.6   1.7   0.9
# 3   0.5   0.5   0.6   0.7   0.8   0.9   1.0   1.1   1.1   1.1   0.5

# %%
investment_private_fixed_assets_industry_healthcare.columns = ['Industry',] + [str(i) + '_fixed_assets' for i in range(1975, 1991)]
investment_private_fixed_assets_industry_healthcare.columns
# Out:
# Index(['Industry', '1975_fixed_assets', '1976_fixed_assets',
#        '1977_fixed_assets', '1978_fixed_assets', '1979_fixed_assets',
#        '1980_fixed_assets', '1981_fixed_assets', '1982_fixed_assets',
#        '1983_fixed_assets', '1984_fixed_assets', '1985_fixed_assets',
#        '1986_fixed_assets', '1987_fixed_assets', '1988_fixed_assets',
#        '1989_fixed_assets', '1990_fixed_assets'],
#       dtype='object')

# %%
def add_year_suffix(df, suffix):
    df = df.copy()

    # Ensure an Industry column exists (first col is index, second is industry in your files)
    if 'Industry' not in df.columns and len(df.columns) >= 2:
        df.rename(columns={df.columns[1]: 'Industry'}, inplace=True)
        # drop first index-like column if it's not Industry
        if df.columns[0] != 'Industry':
            df.drop(columns=[df.columns[0]], inplace=True)

    # If all non-Industry columns already end with this suffix, do nothing
    other = [c for c in df.columns if c != 'Industry']
    if other and all(str(c).endswith(suffix) for c in other):
        return df

    # Rename any column that starts with a 4-digit year to "<year><suffix>"
    rename_map = {}
    for c in df.columns:
        if c == 'Industry':
            continue
        s = str(c).strip()
        m = re.match(r'^(\d{4})', s)  # grab leading year if present
        if m:
            y = m.group(1)
            target = f"{y}{suffix}"
            if s != target:
                rename_map[c] = target

    df = df.rename(columns=rename_map)

    # Keep only Industry + properly suffixed year columns
    keep = ['Industry'] + [col for col in df.columns
                           if col != 'Industry' and re.match(r'^\d{4}' + re.escape(suffix) + r'$', str(col))]
    df = df[keep]
    return df

# %%
# Ensure 'Industry' is column 2 and drop the first index col if needed (if you already have this, keep using it)
def ensure_industry(df):
    df = df.copy()
    if 'Industry' not in df.columns and len(df.columns) >= 2:
        df.rename(columns={df.columns[1]: 'Industry'}, inplace=True)
        if df.columns[0] != 'Industry':
            df.drop(columns=[df.columns[0]], inplace=True)
    df['Industry'] = df['Industry'].astype(str).str.strip()
    return df

h_net   = ensure_industry(current_cost_net_stock_private_fixed_assets_industry_healthcare)
h_equip = ensure_industry(investment_private_equipment_industry_healthcare)
h_fix   = ensure_industry(investment_private_fixed_assets_industry_healthcare)

h_net_s   = add_year_suffix(h_net,   '_net_stock')
h_equip_s = add_year_suffix(h_equip, '_equipment')
h_fix_s   = add_year_suffix(h_fix,   '_fixed_assets')

# Merge by Industry (use how='outer' first to diagnose mismatches if needed)
combined_df_healthcare = (
    h_net_s
      .merge(h_equip_s, on='Industry', how='inner')
      .merge(h_fix_s,   on='Industry', how='inner')
)

combined_df_healthcare.head(12)
# Out:
#                                   Industry  1975_net_stock  1976_net_stock  \
# 0          Ambulatory health care services            26.3            28.5
# 1                                Hospitals            63.3            70.3
# 2  Nursing and residential care facilities             3.7             4.0
# 3                        Social assistance             3.8             4.1
#
#    1977_net_stock  1978_net_stock  1979_net_stock  1980_net_stock  \
# 0            31.8            35.8            41.1            47.1
# 1            79.4            90.3           104.0           118.5
# 2             4.5             5.0             5.8             6.6
# 3             4.6             5.2             5.9             6.7
#
#    1981_net_stock  1982_net_stock  1983_net_stock  ...  1981_fixed_assets  \
# 0            53.2            59.6            66.1  ...                6.6
# 1           131.1           142.7           153.5  ...                9.7
# 2             7.3             8.0             8.7  ...                0.6
# 3             7.4             7.9             8.3  ...                0.5
#
#    1982_fixed_assets  1983_fixed_assets  1984_fixed_assets  1985_fixed_assets  \
# 0                8.6                9.9               11.3               12.1
# 1               12.3               13.6               13.9               14.5
# 2                0.8                0.9                1.1                1.2
# 3                0.6                0.7                0.8                0.9
#
#    1986_fixed_assets  1987_fixed_assets  1988_fixed_assets  1989_fixed_assets  \
# 0               13.2               14.8               15.9               16.9
# 1               16.2               18.4               20.3               22.4
# 2                1.3                1.5                1.6                1.7
# 3                1.0                1.1                1.1                1.1
#
#    1990_fixed_assets
# 0               11.5
# 1               11.6
# 2                0.9
# 3                0.5
#
# [4 rows x 49 columns]

# %%
# Ensure 'Industry' is column 2 and drop the first index col if needed (if you already have this, keep using it)
def ensure_industry(df):
    df = df.copy()
    if 'Industry' not in df.columns and len(df.columns) >= 2:
        df.rename(columns={df.columns[1]: 'Industry'}, inplace=True)
        if df.columns[0] != 'Industry':
            df.drop(columns=[df.columns[0]], inplace=True)
    df['Industry'] = df['Industry'].astype(str).str.strip()
    return df

h_net   = ensure_industry(current_cost_net_stock_private_fixed_assets_industry_manufacturing)
h_equip = ensure_industry(investment_private_equipment_industry_manufacturing)
h_fix   = ensure_industry(investment_private_fixed_assets_industry_manufacturing)

h_net_s   = add_year_suffix(h_net,   '_net_stock')
h_equip_s = add_year_suffix(h_equip, '_equipment')
h_fix_s   = add_year_suffix(h_fix,   '_fixed_assets')

# Merge by Industry (use how='outer' first to diagnose mismatches if needed)
combined_df_manufacturing = (
    h_net_s
      .merge(h_equip_s, on='Industry', how='inner')
      .merge(h_fix_s,   on='Industry', how='inner')
)

combined_df_manufacturing.head(12)
# Out:
#                                             Industry  1975_net_stock  \
# 0                                      Durable goods           247.7
# 1                                      Wood products             9.5
# 2                       Nonmetallic mineral products            19.2
# 3                                     Primary metals            55.5
# 4                          Fabricated metal products            27.0
# 5                                          Machinery            26.5
# 6                   Computer and electronic products            36.7
# 7   Electrical equipment, appliances, and components            14.6
# 8     Motor vehicles, bodies and trailers, and parts            25.6
# 9                     Other transportation equipment            18.6
# 10                    Furniture and related products             2.7
# 11                       Miscellaneous manufacturing            11.8
#
#     1976_net_stock  1977_net_stock  1978_net_stock  1979_net_stock  \
# 0            269.4           299.6           338.7           392.3
# 1             10.4            11.7            13.4            15.6
# 2             20.7            22.8            25.7            29.3
# 3             60.0            66.1            72.5            81.4
# 4             29.7            33.6            38.5            44.9
# 5             29.2            32.9            37.9            44.8
# 6             40.0            44.5            50.7            59.6
# 7             15.8            17.1            19.0            21.7
# 8             27.4            31.0            35.9            42.0
# 9             20.1            21.9            24.7            29.1
# 10             2.9             3.3             3.8             4.3
# 11            13.2            14.8            16.7            19.5
#
#     1980_net_stock  1981_net_stock  1982_net_stock  1983_net_stock  ...  \
# 0            453.7           506.7           538.9           554.2  ...
# 1             17.8            19.0            19.4            19.3  ...
# 2             33.5            36.2            37.3            37.4  ...
# 3             91.4            98.6           101.7           102.1  ...
# 4             52.1            58.1            61.5            62.4  ...
# 5             52.8            60.3            65.7            68.6  ...
# 6             70.7            81.0            89.2            95.1  ...
# 7             25.1            28.0            30.1            31.5  ...
# 8             48.6            55.7            57.2            55.8  ...
# 9             34.3            39.0            43.5            47.1  ...
# 10             5.0             5.4             5.8             6.0  ...
# 11            22.6            25.3            27.5            28.8  ...
#
#     1981_fixed_assets  1982_fixed_assets  1983_fixed_assets  \
# 0                75.6               69.3               66.8
# 1                 2.0                1.5                1.4
# 2                 3.9                3.0                2.8
# 3                 7.6                5.7                5.6
# 4                 6.7                5.6                4.8
# 5                 9.4                9.1                8.2
# 6                17.1               17.9               18.4
# 7                 4.3                4.2                4.4
# 8                13.3                9.5                8.2
# 9                 7.0                8.2                8.7
# 10                0.6                0.6                0.7
# 11                3.7                4.0                3.7
#
#     1984_fixed_assets  1985_fixed_assets  1986_fixed_assets  \
# 0                82.2               91.6               88.4
# 1                 1.8                1.8                1.8
# 2                 3.8                4.6                4.2
# 3                 5.6                6.4                4.6
# 4                 6.2                6.9                6.7
# 5                 9.9               10.5                9.0
# 6                22.7               24.4               23.3
# 7                 5.2                5.2                5.0
# 8                11.0               13.6               15.0
# 9                10.9               12.5               13.5
# 10                0.8                0.8                0.9
# 11                4.3                4.7                4.4
#
#     1987_fixed_assets  1988_fixed_assets  1989_fixed_assets  1990_fixed_assets
# 0                88.8               89.2               99.9              103.6
# 1                 1.9                1.8                2.1                2.0
# 2                 4.3                4.0                4.8                4.8
# 3                 5.2                5.9                6.9                7.4
# 4                 6.7                6.5                7.4                7.8
# 5                 8.9                9.3               10.7               11.4
# 6                24.1               25.8               27.9               29.3
# 7                 4.0                4.5                5.0                5.3
# 8                14.5               12.5               15.5               16.3
# 9                13.3               12.9               13.0               12.5
# 10                0.9                1.0                1.1                1.0
# 11                5.0                5.0                5.6                5.8
#
# [12 rows x 49 columns]

# %%
# --- helper: melt one metric from wide to long ---
def melt_metric(df, metric_suffix, value_name):
    # columns like "1975_net_stock" or "1975_fixed_assets"
    pattern = re.compile(r"^(\d{4})_" + re.escape(metric_suffix) + r"$")
    year_cols = [c for c in df.columns if pattern.match(c)]
    long = df.melt(
        id_vars=["Industry"],
        value_vars=year_cols,
        var_name="year_metric",
        value_name=value_name
    )
    long["Year"] = long["year_metric"].str.extract(r"^(\d{4})").astype(int)
    long = long.drop(columns=["year_metric"])
    return long

# Tag groups
healthcare = combined_df_healthcare.copy()
healthcare["Group"] = "Healthcare"

manufacturing = combined_df_manufacturing.copy()
manufacturing["Group"] = "Manufacturing"

# Melt each metric for each group
def build_group_long(df):
    net  = melt_metric(df, "net_stock",     "net_stock")
    eqp  = melt_metric(df, "equipment",     "investment_equipment")
    fix  = melt_metric(df, "fixed_assets",  "investment_fixed_assets")
    out = (
        net
        .merge(eqp, on=["Industry","Year"], how="outer")
        .merge(fix, on=["Industry","Year"], how="outer")
    )
    # reattach Group
    out = out.merge(df[["Industry","Group"]].drop_duplicates(), on="Industry", how="left")
    return out

long_health = build_group_long(healthcare)
long_manuf  = build_group_long(manufacturing)

panel = pd.concat([long_health, long_manuf], ignore_index=True)

# Outcome(s): investment rates (per unit of net stock)
for col in ["investment_equipment","investment_fixed_assets"]:
    panel[col + "_rate"] = panel[col] / panel["net_stock"]

# Keep analysis window if you want (1985–1990)
panel = panel[(panel["Year"]>=1975) & (panel["Year"]<=1990)].copy()

# DiD variables
panel["treated"] = (panel["Group"]=="Manufacturing").astype(int)
panel["post"]    = (panel["Year"]>=1981).astype(int)
panel["did"]     = panel["treated"]*panel["post"]

# Quick sanity check
panel.head(100)
# Out:
#                                             Industry  net_stock  Year  \
# 0                    Ambulatory health care services       26.3  1975
# 1                    Ambulatory health care services       28.5  1976
# 2                    Ambulatory health care services       31.8  1977
# 3                    Ambulatory health care services       35.8  1978
# 4                    Ambulatory health care services       41.1  1979
# ..                                               ...        ...   ...
# 95                                     Durable goods      784.2  1990
# 96  Electrical equipment, appliances, and components       14.6  1975
# 97  Electrical equipment, appliances, and components       15.8  1976
# 98  Electrical equipment, appliances, and components       17.1  1977
# 99  Electrical equipment, appliances, and components       19.0  1978
#
#     investment_equipment  investment_fixed_assets          Group  \
# 0                    1.8                      2.4     Healthcare
# 1                    2.1                      2.7     Healthcare
# 2                    2.5                      3.1     Healthcare
# 3                    3.0                      3.8     Healthcare
# 4                    3.2                      4.3     Healthcare
# ..                   ...                      ...            ...
# 95                  44.0                    103.6  Manufacturing
# 96                   0.7                      2.0  Manufacturing
# 97                   0.8                      2.2  Manufacturing
# 98                   0.9                      2.3  Manufacturing
# 99                   1.1                      2.7  Manufacturing
#
#     investment_equipment_rate  investment_fixed_assets_rate  treated  post  \
# 0                    0.068441                      0.091255        0     0
# 1                    0.073684                      0.094737        0     0
# 2                    0.078616                      0.097484        0     0
# 3                    0.083799                      0.106145        0     0
# 4                    0.077859                      0.104623        0     0
# ..                        ...                           ...      ...   ...
# 95                   0.056108                      0.132109        1     1
# 96                   0.047945                      0.136986        1     0
# 97                   0.050633                      0.139241        1     0
# 98                   0.052632                      0.134503        1     0
# 99                   0.057895                      0.142105        1     0
#
#     did
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ..  ...
# 95    1
# 96    0
# 97    0
# 98    0
# 99    0
#
# [100 rows x 11 columns]

# %%
# --- 1) Aggregate: average (and optional CI) by Year x Group ---
def summarize_trends(panel, rate_col):
    grp = (
        panel.groupby(["Year", "Group"], as_index=False)[rate_col]
             .agg(mean="mean", count="size", std="std")
    )
    # Optional 95% CI (normal approx). Safe with count>=2; else NaN.
    grp["se"] = grp["std"] / np.sqrt(grp["count"])
    grp["ci_lo"] = grp["mean"] - 1.96*grp["se"]
    grp["ci_hi"] = grp["mean"] + 1.96*grp["se"]
    return grp

equip_trend = summarize_trends(panel, "investment_equipment_rate")
fixed_trend = summarize_trends(panel, "investment_fixed_assets_rate")

# --- 2) Plot helper with pre/post shading and ERTA line ---
def plot_trend(df, title, ylabel):
    plt.figure(figsize=(9,6))

    # Shading for pre/post
    ymin = min(df["ci_lo"].min(skipna=True), df["mean"].min())
    ymax = max(df["ci_hi"].max(skipna=True), df["mean"].max())
    plt.axvspan(1975, 1981, alpha=0.08, label="Pre-ERTA (≤1980)")
    plt.axvspan(1981, 1990, alpha=0.05, label="Post-ERTA (≥1981)")

    # ERTA vertical line
    plt.axvline(1981, linestyle="--", linewidth=1, label="ERTA (1981)")

    # Lines (and optional CI ribbons) per group
    for g in ["Manufacturing", "Healthcare"]:
        sub = df[df["Group"] == g].sort_values("Year")
        plt.plot(sub["Year"], sub["mean"], label=g, linewidth=2)
        # Confidence band if available (won't crash if NaNs)
        if sub["ci_lo"].notna().any():
            plt.fill_between(sub["Year"], sub["ci_lo"], sub["ci_hi"], alpha=0.12)

    plt.title(title)
    plt.xlabel("Year")
    plt.ylabel(ylabel)
    plt.xlim(1975, 1990)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()

# --- 3) Make the two figures ---
plot_trend(
    equip_trend,
    "Trends in Equipment Investment Rates (1975–1990)",
    "Average Equipment Investment Rate"
)

plot_trend(
    fixed_trend,
    "Trends in Fixed-Asset Investment Rates (1975–1990)",
    "Average Fixed-Asset Investment Rate"
)

# %%
# --- 1) Columns to summarize ---
cols = [
    "net_stock",
    "investment_equipment",
    "investment_fixed_assets",
    "investment_equipment_rate",
    "investment_fixed_assets_rate",
]

# --- 2) Label periods (pre/post 1981) ---
panel = panel.copy()
panel["Period"] = np.where(panel["Year"] < 1981, "Pre-ERTA (1975–1980)", "Post-ERTA (1981–1990)")

# (Optional) keep analysis window again, in case anything slipped in
panel = panel[(panel["Year"] >= 1975) & (panel["Year"] <= 1990)]

# --- 3) Separate describe() tables for each Sector x Period ---
def sector_period_describe(df, sector_label, period_label):
    g = df[(df["Group"] == sector_label) & (df["Period"] == period_label)]
    out = g[cols].describe().round(2)
    out.index.name = "Statistic"
    return out

pre_healthcare  = sector_period_describe(panel, "Healthcare",    "Pre-ERTA (1975–1980)")
pre_manu        = sector_period_describe(panel, "Manufacturing", "Pre-ERTA (1975–1980)")
post_healthcare = sector_period_describe(panel, "Healthcare",    "Post-ERTA (1981–1990)")
post_manu       = sector_period_describe(panel, "Manufacturing", "Post-ERTA (1981–1990)")

print("=== Healthcare — Pre-ERTA (1975–1980) ===")
print(pre_healthcare)
print("\n=== Manufacturing — Pre-ERTA (1975–1980) ===")
print(pre_manu)
print("\n=== Healthcare — Post-ERTA (1981–1990) ===")
print(post_healthcare)
print("\n=== Manufacturing — Post-ERTA (1981–1990) ===")
print(post_manu)

# --- 4) One compact table: Period × Group with multiple stats (nice for CSV/TeX) ---
compact = (
    panel.groupby(["Period", "Group"])[cols]
         .agg(["count", "mean", "std", "min", "median", "max"])
         .round(2)
)

print("\n=== Compact Summary (Period × Group) ===")
print(compact)


# --- 6) (Optional) Pretty column order: put rates first, then levels ---
pretty_order = [
    "investment_equipment_rate",
    "investment_fixed_assets_rate",
    "net_stock",
    "investment_equipment",
    "investment_fixed_assets",
]
compact = compact.reindex(columns=pretty_order, level=0)
# Out:
# === Healthcare — Pre-ERTA (1975–1980) ===
#            net_stock  investment_equipment  investment_fixed_assets  \
# Statistic
# count          24.00                 24.00                    24.00
# mean           33.18                  1.61                     2.87
# std            36.03                  1.52                     2.93
# min             3.70                  0.10                     0.20
# 25%             4.90                  0.20                     0.40
# 50%            16.50                  1.05                     1.45
# 75%            51.15                  3.02                     5.30
# max           118.50                  4.10                     8.50
#
#            investment_equipment_rate  investment_fixed_assets_rate
# Statistic
# count                          24.00                         24.00
# mean                            0.05                          0.08
# std                             0.02                          0.01
# min                             0.02                          0.05
# 25%                             0.04                          0.07
# 50%                             0.04                          0.08
# 75%                             0.06                          0.09
# max                             0.08                          0.11
#
# === Manufacturing — Pre-ERTA (1975–1980) ===
#            net_stock  investment_equipment  investment_fixed_assets  \
# Statistic
# count          78.00                 78.00                    78.00
# mean           72.30                  5.11                     9.63
# std           104.57                  7.43                    13.81
# min             2.70                  0.10                     0.30
# 25%            18.70                  1.32                     2.32
# 50%            29.50                  2.25                     4.25
# 75%            54.82                  3.90                     7.85
# max           453.70                 33.00                    65.40
#
#            investment_equipment_rate  investment_fixed_assets_rate
# Statistic
# count                          78.00                         78.00
# mean                            0.07                          0.14
# std                             0.02                          0.04
# min                             0.04                          0.07
# 25%                             0.06                          0.12
# 50%                             0.07                          0.14
# 75%                             0.08                          0.15
# max                             0.11                          0.23
#
# === Healthcare — Post-ERTA (1981–1990) ===
#            net_stock  investment_equipment  investment_fixed_assets  \
# Statistic
# count          40.00                 40.00                    40.00
# mean           73.10                  4.13                     7.34
# std            75.68                  4.02                     6.99
# min             7.30                  0.20                     0.50
# 25%            10.35                  0.48                     0.98
# 50%            34.50                  2.65                     4.15
# 75%           126.08                  7.15                    13.30
# max           246.40                 11.60                    22.40
#
#            investment_equipment_rate  investment_fixed_assets_rate
# Statistic
# count                          40.00                         40.00
# mean                            0.05                          0.10
# std                             0.02                          0.03
# min                             0.03                          0.04
# 25%                             0.04                          0.09
# 50%                             0.04                          0.10
# 75%                             0.06                          0.12
# max                             0.10                          0.15
#
# === Manufacturing — Post-ERTA (1981–1990) ===
#            net_stock  investment_equipment  investment_fixed_assets  \
# Statistic
# count         130.00                130.00                   130.00
# mean          138.10                  8.25                    17.47
# std           195.15                 11.80                    24.65
# min             5.40                  0.40                     0.60
# 25%            37.00                  2.20                     4.30
# 50%            64.45                  3.60                     6.90
# 75%           104.10                  5.38                    14.88
# max           784.20                 45.70                   103.60
#
#            investment_equipment_rate  investment_fixed_assets_rate
# Statistic
# count                         130.00                        130.00
# mean                            0.06                          0.13
# std                             0.01                          0.04
# min                             0.03                          0.04
# 25%                             0.05                          0.10
# 50%                             0.06                          0.12
# 75%                             0.07                          0.15
# max                             0.13                          0.24
#
# === Compact Summary (Period × Group) ===
#                                     net_stock                              \
#                                         count    mean     std  min median
# Period                Group
# Post-ERTA (1981–1990) Healthcare           40   73.10   75.68  7.3  34.50
#                       Manufacturing       130  138.10  195.15  5.4  64.45
# Pre-ERTA (1975–1980)  Healthcare           24   33.18   36.03  3.7  16.50
#                       Manufacturing        78   72.30  104.57  2.7  29.50
#
#                                            investment_equipment               \
#                                        max                count  mean    std
# Period                Group
# Post-ERTA (1981–1990) Healthcare     246.4                   40  4.13   4.02
#                       Manufacturing  784.2                  130  8.25  11.80
# Pre-ERTA (1975–1980)  Healthcare     118.5                   24  1.61   1.52
#                       Manufacturing  453.7                   78  5.11   7.43
#
#                                           ... investment_equipment_rate        \
#                                      min  ...                       std   min
# Period                Group               ...
# Post-ERTA (1981–1990) Healthcare     0.2  ...                      0.02  0.03
#                       Manufacturing  0.4  ...                      0.01  0.03
# Pre-ERTA (1975–1980)  Healthcare     0.1  ...                      0.02  0.02
#                       Manufacturing  0.1  ...                      0.02  0.04
#
#                                                  investment_fixed_assets_rate  \
#                                     median   max                        count
# Period                Group
# Post-ERTA (1981–1990) Healthcare      0.04  0.10                           40
#                       Manufacturing   0.06  0.13                          130
# Pre-ERTA (1975–1980)  Healthcare      0.04  0.08                           24
#                       Manufacturing   0.07  0.11                           78
#
#
#                                      mean   std   min median   max
# Period                Group
# Post-ERTA (1981–1990) Healthcare     0.10  0.03  0.04   0.10  0.15
#                       Manufacturing  0.13  0.04  0.04   0.12  0.24
# Pre-ERTA (1975–1980)  Healthcare     0.08  0.01  0.05   0.08  0.11
#                       Manufacturing  0.14  0.04  0.07   0.14  0.23
#
# [4 rows x 30 columns]

# %%
# Log of capital stock (controls for industry size)
panel['log_net_stock'] = np.log(panel['net_stock'] + 1)

# Equipment share (controls for investment composition)
panel['equipment_share'] = panel['investment_equipment'] / panel['investment_fixed_assets']

# Create industry-specific time trends
panel['trend'] = panel['Year'] - panel['Year'].min()

# %%
# Save final panel dataset to CSV
panel.to_csv("/Users/tanishagauns/Desktop/Project paper/panel_data.csv", index=False)
print("Panel dataset saved successfully!")
# Out:
# Panel dataset saved successfully!

# %%
# ------------- TWFE DiD -------------
Y = "investment_equipment_rate"
# Define the full regression formula
formula = """
investment_equipment_rate ~ did + 
    C(Industry) + C(Year) + 
    log_net_stock + 
    equipment_share
"""
did_fit = smf.ols(formula, data=panel).fit(
    cov_type="cluster",
    cov_kwds={"groups": panel["Industry"]}
)

print("\n=== TWFE DiD: Equipment Investment Rate ===")
print(did_fit.summary())
print("\nDiD (treated×post) estimate:",
      f"{did_fit.params['did']:.6f}",
      "SE:", f"{did_fit.bse['did']:.6f}",
      "p:", f"{did_fit.pvalues['did']:.3g}")

# Save coefficient table if you want to use it in your paper appendix
coef_table = pd.DataFrame({
    "term": did_fit.params.index,
    "estimate": did_fit.params.values,
    "std_error": did_fit.bse.values,
    "p_value": did_fit.pvalues.values
})
coef_table.to_csv("did_equipment_rate_coefficients.csv", index=False)
print("\nSaved: did_equipment_rate_coefficients.csv")
# Out:
# === TWFE DiD: Equipment Investment Rate ===
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     investment_equipment_rate   R-squared:                       0.814
# Model:                                   OLS   Adj. R-squared:                  0.787
# Method:                        Least Squares   F-statistic:                     688.9
# Date:                       Tue, 14 Oct 2025   Prob (F-statistic):           1.24e-19
# Time:                               14:42:25   Log-Likelihood:                 945.99
# No. Observations:                        272   AIC:                            -1822.
# Df Residuals:                            237   BIC:                            -1696.
# Df Model:                                 34
# Covariance Type:                     cluster
# ===================================================================================================================================
#                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                          -0.0629      0.029     -2.183      0.029      -0.119      -0.006
# C(Industry)[T.Computer and electronic products]                     0.0007      0.008      0.092      0.927      -0.014       0.015
# C(Industry)[T.Durable goods]                                       -0.0652      0.019     -3.474      0.001      -0.102      -0.028
# C(Industry)[T.Electrical equipment, appliances, and components]     0.0208      0.007      2.788      0.005       0.006       0.035
# C(Industry)[T.Fabricated metal products]                           -0.0066      0.003     -2.112      0.035      -0.013      -0.000
# C(Industry)[T.Furniture and related products]                       0.0655      0.019      3.471      0.001       0.028       0.102
# C(Industry)[T.Hospitals]                                           -0.0597      0.008     -7.255      0.000      -0.076      -0.044
# C(Industry)[T.Machinery]                                           -0.0012      0.005     -0.263      0.793      -0.010       0.008
# C(Industry)[T.Miscellaneous manufacturing]                          0.0297      0.008      3.794      0.000       0.014       0.045
# C(Industry)[T.Motor vehicles, bodies and trailers, and parts]       0.0226      0.006      3.782      0.000       0.011       0.034
# C(Industry)[T.Nondurable goods]                                    -0.0623      0.016     -3.839      0.000      -0.094      -0.030
# C(Industry)[T.Nonmetallic mineral products]                         0.0087      0.006      1.567      0.117      -0.002       0.020
# C(Industry)[T.Nursing and residential care facilities]              0.0265      0.015      1.713      0.087      -0.004       0.057
# C(Industry)[T.Other transportation equipment]                       0.0039      0.008      0.503      0.615      -0.011       0.019
# C(Industry)[T.Primary metals]                                      -0.0441      0.004    -10.212      0.000      -0.053      -0.036
# C(Industry)[T.Social assistance]                                    0.0220      0.016      1.391      0.164      -0.009       0.053
# C(Industry)[T.Wood products]                                        0.0347      0.011      3.146      0.002       0.013       0.056
# C(Year)[T.1976]                                                    -0.0005      0.002     -0.291      0.771      -0.004       0.003
# C(Year)[T.1977]                                                    -0.0001      0.002     -0.095      0.924      -0.003       0.003
# C(Year)[T.1978]                                                     0.0003      0.003      0.107      0.915      -0.005       0.006
# C(Year)[T.1979]                                                    -0.0051      0.003     -1.576      0.115      -0.012       0.001
# C(Year)[T.1980]                                                    -0.0105      0.005     -2.075      0.038      -0.020      -0.001
# C(Year)[T.1981]                                                    -0.0011      0.008     -0.147      0.883      -0.016       0.014
# C(Year)[T.1982]                                                    -0.0128      0.009     -1.408      0.159      -0.031       0.005
# C(Year)[T.1983]                                                    -0.0171      0.010     -1.773      0.076      -0.036       0.002
# C(Year)[T.1984]                                                    -0.0104      0.009     -1.106      0.269      -0.029       0.008
# C(Year)[T.1985]                                                    -0.0118      0.009     -1.256      0.209      -0.030       0.007
# C(Year)[T.1986]                                                    -0.0188      0.010     -1.952      0.051      -0.038     7.9e-05
# C(Year)[T.1987]                                                    -0.0220      0.010     -2.242      0.025      -0.041      -0.003
# C(Year)[T.1988]                                                    -0.0256      0.011     -2.318      0.020      -0.047      -0.004
# C(Year)[T.1989]                                                    -0.0224      0.011     -2.055      0.040      -0.044      -0.001
# C(Year)[T.1990]                                                    -0.0306      0.011     -2.744      0.006      -0.052      -0.009
# did                                                                -0.0140      0.005     -2.920      0.003      -0.023      -0.005
# log_net_stock                                                       0.0303      0.008      3.627      0.000       0.014       0.047
# equipment_share                                                     0.0507      0.017      2.993      0.003       0.017       0.084
# ==============================================================================
# Omnibus:                       17.316   Durbin-Watson:                   1.118
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.913
# Skew:                           0.157   Prob(JB):                     6.50e-11
# Kurtosis:                       5.010   Cond. No.                         390.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# DiD (treated×post) estimate: -0.013951 SE: 0.004777 p: 0.0035
#
# Saved: did_equipment_rate_coefficients.csv
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 34, but rank is 16
#   warnings.warn('covariance of constraints does not have full '

# %%
# Load the panel data
panel_industry_investment_rates= pd.read_csv("/Users/tanishagauns/Desktop/Project paper/panel_data.csv")

# Check columns
print(panel_industry_investment_rates.columns)
# Out:
# Index(['Industry', 'net_stock', 'Year', 'investment_equipment',
#        'investment_fixed_assets', 'Group', 'investment_equipment_rate',
#        'investment_fixed_assets_rate', 'treated', 'post', 'did', 'Period',
#        'log_net_stock', 'equipment_share', 'trend'],
#       dtype='object')

# %%
# Plot average investment rate by Year and Treatment group
panel_industry_investment_rates.groupby(['Year', 'treated'])['investment_equipment_rate'].mean().unstack().plot(
    figsize=(8,5),
    marker='o'
)

# Add ERTA policy marker
plt.axvline(1981, color='red', linestyle='--', label='ERTA 1981')
plt.title("Pre/Post Trends in Equipment Investment Rate")
plt.ylabel("Average Equipment Investment Rate")
plt.legend(['Healthcare (0)', 'Manufacturing (1)', 'ERTA 1981'])
plt.show()

# %%
# Ensure types
panel_industry_investment_rates['Year'] = panel_industry_investment_rates['Year'].astype(int)

# 2) OLS with year-by-year interactions (event study)
# Use 1980 as the omitted (baseline) year so coefficients are relative to 1980
formula = "investment_equipment_rate ~ C(Year, Treatment(reference=1980))*treated + C(Industry)"

# Cluster by Industry if present; otherwise fall back to robust
if 'Industry' in panel_industry_investment_rates.columns:
    model = smf.ols(
        formula,
        data=panel_industry_investment_rates
    ).fit(cov_type="cluster", cov_kwds={"groups": panel_industry_investment_rates["Industry"]})
else:
    model = smf.ols(formula, data=panel_industry_investment_rates).fit(cov_type="HC1")

# 3) Pull interaction terms: C(Year,...)[T.YYYY]:treated
coef = model.params
se   = model.bse

pattern = re.compile(r"C\(Year.*\)\[T\.(\d+)\]:treated")  # captures the year
rows = []
for name, value in coef.items():
    m = pattern.search(name)
    if m:
        yr = int(m.group(1))
        rows.append((yr, value, se[name]))

results_df = pd.DataFrame(rows, columns=["year", "coef", "se"]).sort_values("year")
results_df["ci_lower"] = results_df["coef"] - 1.96 * results_df["se"]
results_df["ci_upper"] = results_df["coef"] + 1.96 * results_df["se"]

# 4) Plot
plt.figure(figsize=(9,6))
plt.axhline(0, color='black', linewidth=1)
plt.axvline(1981, color='red', linestyle='--', label='ERTA 1981')  # policy date
plt.plot(results_df["year"], results_df["coef"], marker='o', label='Estimated βₜ (vs 1980)')
plt.fill_between(results_df["year"], results_df["ci_lower"], results_df["ci_upper"], alpha=0.2)
plt.title("Event Study: Dynamic Treatment Effects on Equipment Investment Rate")
plt.xlabel("Year (baseline = 1980)")
plt.ylabel("Effect on investment_equipment_rate")
plt.legend()
plt.tight_layout()
plt.show()
